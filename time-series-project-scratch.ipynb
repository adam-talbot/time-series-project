# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('figure', figsize=(13, 7))
plt.rc('font', size=13)

# %%
df = pd.read_csv('GlobalLandTemperaturesByCity.csv')

# %%
df.shape
# Out:
# (8599212, 7)

# %%
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
df = df[df.City == 'Phoenix']

# %%
df.shape
# Out:
# (2145, 7)

# %%
df.head()
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 5854084  1835-01-01              11.544                          2.167
# 5854085  1835-02-01              11.412                          2.386
# 5854086  1835-03-01              14.308                          2.441
# 5854087  1835-04-01              18.443                          2.570
# 5854088  1835-05-01              23.092                          2.250
#
#             City        Country Latitude Longitude
# 5854084  Phoenix  United States   32.95N   112.02W
# 5854085  Phoenix  United States   32.95N   112.02W
# 5854086  Phoenix  United States   32.95N   112.02W
# 5854087  Phoenix  United States   32.95N   112.02W
# 5854088  Phoenix  United States   32.95N   112.02W

# %%
df = df.rename(columns={'AverageTemperature' : 'ave_temp', 'dt' : 'Date'})

# %%
df.head()
# Out:
#                Date  ave_temp  AverageTemperatureUncertainty     City  \
# 5854084  1835-01-01    11.544                          2.167  Phoenix
# 5854085  1835-02-01    11.412                          2.386  Phoenix
# 5854086  1835-03-01    14.308                          2.441  Phoenix
# 5854087  1835-04-01    18.443                          2.570  Phoenix
# 5854088  1835-05-01    23.092                          2.250  Phoenix
#
#                Country Latitude Longitude
# 5854084  United States   32.95N   112.02W
# 5854085  United States   32.95N   112.02W
# 5854086  United States   32.95N   112.02W
# 5854087  United States   32.95N   112.02W
# 5854088  United States   32.95N   112.02W

# %%
df.Date = pd.to_datetime(df.Date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2145 entries, 5854084 to 5856228
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date                           2145 non-null   datetime64[ns]
#  1   ave_temp                       2139 non-null   float64
#  2   AverageTemperatureUncertainty  2139 non-null   float64
#  3   City                           2145 non-null   object
#  4   Country                        2145 non-null   object
#  5   Latitude                       2145 non-null   object
#  6   Longitude                      2145 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 134.1+ KB

# %%
df = df.set_index('Date')

# %%
type(df.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# s = df.AverageTemperature

# %%
df.index.max()
# Out:
# Timestamp('2013-09-01 00:00:00')

# %%
df.index.min()
# Out:
# Timestamp('1835-01-01 00:00:00')

# %%
df.isna().sum()
# Out:
# ave_temp                         6
# AverageTemperatureUncertainty    6
# City                             0
# Country                          0
# Latitude                         0
# Longitude                        0
# dtype: int64

# %%
df[np.isnan(df.ave_temp)]
# Out:
#             ave_temp  AverageTemperatureUncertainty     City        Country  \
# Date
# 1843-03-01       NaN                            NaN  Phoenix  United States
# 1848-01-01       NaN                            NaN  Phoenix  United States
# 1848-02-01       NaN                            NaN  Phoenix  United States
# 1848-03-01       NaN                            NaN  Phoenix  United States
# 1848-04-01       NaN                            NaN  Phoenix  United States
# 1848-05-01       NaN                            NaN  Phoenix  United States
#
#            Latitude Longitude
# Date
# 1843-03-01   32.95N   112.02W
# 1848-01-01   32.95N   112.02W
# 1848-02-01   32.95N   112.02W
# 1848-03-01   32.95N   112.02W
# 1848-04-01   32.95N   112.02W
# 1848-05-01   32.95N   112.02W

# %%
plt.figure(figsize=(50, 10))
df.ave_temp.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.shape
# Out:
# (2145, 6)

# %%
df.head()
# Out:
#             ave_temp  AverageTemperatureUncertainty     City        Country  \
# Date
# 1835-01-01    11.544                          2.167  Phoenix  United States
# 1835-02-01    11.412                          2.386  Phoenix  United States
# 1835-03-01    14.308                          2.441  Phoenix  United States
# 1835-04-01    18.443                          2.570  Phoenix  United States
# 1835-05-01    23.092                          2.250  Phoenix  United States
#
#            Latitude Longitude
# Date
# 1835-01-01   32.95N   112.02W
# 1835-02-01   32.95N   112.02W
# 1835-03-01   32.95N   112.02W
# 1835-04-01   32.95N   112.02W
# 1835-05-01   32.95N   112.02W

# %%
# convert from C to F
def C_to_F(temp):
    return (temp * (9/5) + 32)

# %%
C_to_F(11.5)
# Out:
# 52.7

# %%
df.sort_index()
# Out:
#             ave_temp  AverageTemperatureUncertainty     City        Country  \
# Date
# 1835-01-01    11.544                          2.167  Phoenix  United States
# 1835-02-01    11.412                          2.386  Phoenix  United States
# 1835-03-01    14.308                          2.441  Phoenix  United States
# 1835-04-01    18.443                          2.570  Phoenix  United States
# 1835-05-01    23.092                          2.250  Phoenix  United States
# ...              ...                            ...      ...            ...
# 2013-05-01    25.926                          0.326  Phoenix  United States
# 2013-06-01    31.800                          0.223  Phoenix  United States
# 2013-07-01    33.059                          0.263  Phoenix  United States
# 2013-08-01    32.225                          0.522  Phoenix  United States
# 2013-09-01    29.136                          0.702  Phoenix  United States
#
#            Latitude Longitude
# Date
# 1835-01-01   32.95N   112.02W
# 1835-02-01   32.95N   112.02W
# 1835-03-01   32.95N   112.02W
# 1835-04-01   32.95N   112.02W
# 1835-05-01   32.95N   112.02W
# ...             ...       ...
# 2013-05-01   32.95N   112.02W
# 2013-06-01   32.95N   112.02W
# 2013-07-01   32.95N   112.02W
# 2013-08-01   32.95N   112.02W
# 2013-09-01   32.95N   112.02W
#
# [2145 rows x 6 columns]

# %%
s = df['ave_temp']

# %%
s['1983':].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
s = s.apply(C_to_F)

# %%
s['2000':].plot();

# %%
s
# Out:
# Date
# 1835-01-01    52.7792
# 1835-02-01    52.5416
# 1835-03-01    57.7544
# 1835-04-01    65.1974
# 1835-05-01    73.5656
#                ...
# 2013-05-01    78.6668
# 2013-06-01    89.2400
# 2013-07-01    91.5062
# 2013-08-01    90.0050
# 2013-09-01    84.4448
# Name: ave_temp, Length: 2145, dtype: float64
